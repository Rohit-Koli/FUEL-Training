# %%
# its supervised machine learining classification algorithm.
# which is used to predict probabilities of target variable.
# types of logistic regression
# 1. Binary classification
# 2. Muliticlass classification

# %%
# sf = 1 / 1 + e ^ - y
# y = mx + c
# e = e is the base of natural logarithm (approximately 2.71820)
# Out:
# hello world

# %%
import pandas as pd
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
n = 15
i = 0 
j = n-1
r = n//2
q = n//2
for s in range(n):
    for d in range(n):
        if(s==0 or s==n-1 or d==0 or d==n-1 or d==n//2 or s==n//2):
            print("*",end=" ")
        elif(d==i or d==j or d==r or d==q):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    i += 1
    j -= 1
    if(s<n//2):
        r -= 1
        q += 1
    else:
        r += 1
        q -= 1
    print()
# Out:
# * * * * * * * * * * * * * * *
# * *         * * *         * *
# *   *     *   *   *     *   *
# *     * *     *     * *     *
# *     * *     *     * *     *
# *   *     *   *   *     *   *
# * *         * * *         * *
# * * * * * * * * * * * * * * *
# * *         * * *         * *
# *   *     *   *   *     *   *
# *     * *     *     * *     *
# *     * *     *     * *     *
# *   *     *   *   *     *   *
# * *         * * *         * *
# * * * * * * * * * * * * * * *

# %%
# <-- CONFUSION MATRIX -->

# TP   FP

# FN   TN

# %%
n = 20
s = 0
e = n-1
for i in range(n):
    if(i==0 or i==n-1 or i==n//2 or i==n//2-1 or i==n//2+1):
        print("x",end=" ");
    else:
        print("*",end=" ");
print()
for i in range(n):
    if(i!=n//2):
        print("*",end=" ");
    else:
        print("-",end=" ");
print()
for i in range(n):
    print("*",end=" ");
print()
for i in range(n//2+1):
    for j in range(n):
        if(i==0):
            print("*",end=" ");
        elif(j>=s and j<=e):
            print("*",end=" ");
        else:
            print("-",end=" ");
    if(i < n//2):
        s += 1
        e -= 1
    print()
# Out:
# x * * * x x x * * x
# * * * * * - * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# - * * * * * * * * -
# - - * * * * * * - -
# - - - * * * * - - -
# - - - - * * - - - -
# - - - - - - - - - -
